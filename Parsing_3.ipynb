# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
from time import sleep

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'

URL_FIRST_PAGE_HH = 'https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text='

# %%
headers = {
    'User-Agent': USER_AGENT,
}

# %%
def parse_hh(url_page, headers, result=[]):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
      print('Парсинг завершен')
      return result
    else:
      print('Cсылка: %s'%response.url)

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
      result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
      link_next_page =  'https://spb.hh.ru' + link_next_page['href']
    else:
      print('Парсинг завершен')
      return result

    result = parse_hh(link_next_page, headers, result)   
    return result
     
def parse_vacancy_hh(dom_vacancy):
  sleep(0.1)
  vacancy_name = dom_vacancy.find('a').text

  vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
  if vacancy_salary:
    vacancy_salary = vacancy_salary.text
    min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
  else:
    min_salary, max_salary, currency_salary = None, None, None

  vacancy_link = dom_vacancy.find('a')['href']
  
  return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
  }

def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
  list_salary = vacancy_salary_text.replace('\u202f', '').split()
  for i in range(len(list_salary) - 1):
    if list_salary[i] == 'от':
      min_salary = int(list_salary[i + 1])
    elif list_salary[i] == 'до':
      max_salary = int(list_salary[i + 1])
    elif list_salary[i] == '–':
      min_salary = int(list_salary[i - 1])
      max_salary = int(list_salary[i + 1])
  currency_salary = list_salary[-1]

  return min_salary, max_salary, currency_salary

# %%
result = parse_hh(URL_FIRST_PAGE_HH, headers)
# Out:
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=1&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=2&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=3&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=4&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=5&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=6&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=7&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=8&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=9&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=10&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=11&hhtmFrom=vacancy_search_list
# Cсылка: https://spb.hh.ru/search/vacancy?text=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA&from=suggest_post&salary=&area=88&no_magic=true&ored_clusters=true&items_on_page=20&enable_snippets=true&excluded_text=&page=12&hhtmFrom=vacancy_search_list
# Парсинг завершен

# %%
len(result)
# Out:
# 241

# %%
result
# Out:
# [{'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76914898?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76698999?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '45\u202f000 – 50\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76699527?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77648013?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': '42\u202f600 – 60\u202f000 руб.',
#   'min_salary': 42600,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77560803?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'до 57\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 57000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77522629?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик, подработка',
#   'vacancy_salary': '36\u202f000 – 42\u202f000 руб.',
#   'min_salary': 36000,
#   'max_salary': 42000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76016525?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-упаковщик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77414261?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик молочной продукции (подработка)',
#   'vacancy_salary': '2\u202f145 – 47\u202f190 руб.',
#   'min_salary': 2145,
#   'max_salary': 47190,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77486230?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сотрудник склада/грузчик',
#   'vacancy_salary': '45\u202f000 – 50\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77209168?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '57\u202f200 – 68\u202f200 руб.',
#   'min_salary': 57200,
#   'max_salary': 68200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77636900?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77462014?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад (М.Кабаны)',
#   'vacancy_salary': 'от 41\u202f200 руб.',
#   'min_salary': 41200,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77261697?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77585858?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик МСЦ',
#   'vacancy_salary': '35\u202f000 – 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75657738?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 78\u202f000 руб.',
#   'min_salary': 78000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/66690431?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'до 57\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 57000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77653986?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77602693?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '45\u202f000 – 50\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76982663?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-экспедитор',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77329407?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик/Фасовщик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77535954?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '35\u202f000 – 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73390273?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на производство',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77203811?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Работник склада/грузчик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77655122?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '31\u202f890 – 31\u202f890 руб.',
#   'min_salary': 31890,
#   'max_salary': 31890,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76998578?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '36\u202f000 – 36\u202f000 руб.',
#   'min_salary': 36000,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77549045?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик / Укладчик / Упаковщик',
#   'vacancy_salary': 'от 55\u202f000 руб.',
#   'min_salary': 55000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77068397?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76109998?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 75\u202f000 руб.',
#   'min_salary': 75000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77464063?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77590964?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик. ПГТ Киндери',
#   'vacancy_salary': '39\u202f000 – 49\u202f000 руб.',
#   'min_salary': 39000,
#   'max_salary': 49000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77597527?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Рабочий склада/Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77489684?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 36\u202f960 руб.',
#   'min_salary': 36960,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76134684?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': '35\u202f000 – 38\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 38000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77672670?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77329876?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-наборщик',
#   'vacancy_salary': 'от 38\u202f000 руб.',
#   'min_salary': 38000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77130804?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '30\u202f000 – 40\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77520711?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сборщик-грузчик',
#   'vacancy_salary': '44\u202f000 – 50\u202f000 руб.',
#   'min_salary': 44000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76576897?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77286286?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-грузчик',
#   'vacancy_salary': '40\u202f000 – 60\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77461863?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-кладовщик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76507971?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на производство',
#   'vacancy_salary': 'от 34\u202f500 руб.',
#   'min_salary': 34500,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77581037?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': '35\u202f000 – 45\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77450427?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': '44\u202f000 – 48\u202f000 руб.',
#   'min_salary': 44000,
#   'max_salary': 48000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76841289?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 38\u202f000 руб.',
#   'min_salary': 38000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76725510?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик в ТЦ Мега',
#   'vacancy_salary': 'от 28\u202f000 руб.',
#   'min_salary': 28000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77548436?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'до 57\u202f200 руб.',
#   'min_salary': None,
#   'max_salary': 57200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77319387?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77489704?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик на склад',
#   'vacancy_salary': 'от 36\u202f400 руб.',
#   'min_salary': 36400,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77403628?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Водитель погрузчика-грузчик',
#   'vacancy_salary': 'от 55\u202f000 руб.',
#   'min_salary': 55000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77092938?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77496736?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик ЛПЦ',
#   'vacancy_salary': 'до 36\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77577614?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77410772?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '25\u202f000 – 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': 25000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76772022?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': '57\u202f200 – 60\u202f000 руб.',
#   'min_salary': 57200,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77435619?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76994851?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '37\u202f000 – 45\u202f000 руб.',
#   'min_salary': 37000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72534915?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77526310?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73310507?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Экспедитор-грузчик',
#   'vacancy_salary': '25\u202f000 – 25\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': 25000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77290839?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Работник склада (пр. Победы)',
#   'vacancy_salary': '39\u202f550 – 45\u202f200 руб.',
#   'min_salary': 39550,
#   'max_salary': 45200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77461063?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 26\u202f000 руб.',
#   'min_salary': 26000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77072087?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-кладовщик',
#   'vacancy_salary': '35\u202f000 – 40\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76627033?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-грузчик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77317929?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-Транспортировщик',
#   'vacancy_salary': 'от 52\u202f000 руб.',
#   'min_salary': 52000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77068137?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик (цех№5)',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76073595?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '35\u202f000 – 40\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77122804?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик ТЦ Тандем',
#   'vacancy_salary': 'от 28\u202f000 руб.',
#   'min_salary': 28000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75625701?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 30\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77010878?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик отдел складской логистики',
#   'vacancy_salary': 'до 40\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68119384?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-разнорабочий на склад (Казань)',
#   'vacancy_salary': '57\u202f200 – 85\u202f000 руб.',
#   'min_salary': 57200,
#   'max_salary': 85000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77145714?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '27\u202f200 – 38\u202f080 руб.',
#   'min_salary': 27200,
#   'max_salary': 38080,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76793171?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-координатор',
#   'vacancy_salary': '35\u202f000 – 40\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76709653?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Экспедитор-грузчик',
#   'vacancy_salary': '35\u202f000 – 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72294688?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад',
#   'vacancy_salary': '37\u202f000 – 45\u202f000 руб.',
#   'min_salary': 37000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72535158?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/69665301?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на пищевое производство',
#   'vacancy_salary': 'до 68\u202f200 руб.',
#   'min_salary': None,
#   'max_salary': 68200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77004662?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-наборщик (Биек Тау)',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76883583?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 52\u202f000 руб.',
#   'min_salary': 52000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77068275?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик (Высокая гора)',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77216873?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': '57\u202f200 – 60\u202f000 руб.',
#   'min_salary': 57200,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77435619?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик в цех тары и посуды',
#   'vacancy_salary': '30\u202f000 – 32\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 32000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76901662?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Экспедитор-грузчик',
#   'vacancy_salary': '35\u202f000 – 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72294688?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76595516?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-грузчик',
#   'vacancy_salary': '34\u202f000 – 46\u202f000 руб.',
#   'min_salary': 34000,
#   'max_salary': 46000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77542829?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-грузчик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77317929?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76896799?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '26\u202f000 – 26\u202f000 руб.',
#   'min_salary': 26000,
#   'max_salary': 26000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76589810?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик отдел складской логистики',
#   'vacancy_salary': 'до 40\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68119384?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'до 30\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 30000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68290498?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Работник склада (пр. Победы)',
#   'vacancy_salary': '39\u202f550 – 45\u202f200 руб.',
#   'min_salary': 39550,
#   'max_salary': 45200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77461063?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик / Упаковщица (упаковщик)',
#   'vacancy_salary': '44\u202f160 – 45\u202f760 руб.',
#   'min_salary': 44160,
#   'max_salary': 45760,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76715965?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77461134?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик (Абсалямова д.22)',
#   'vacancy_salary': '31\u202f000 – 35\u202f500 руб.',
#   'min_salary': 31000,
#   'max_salary': 35500,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77532967?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75573658?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик',
#   'vacancy_salary': '31\u202f000 – 35\u202f000 руб.',
#   'min_salary': 31000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76953648?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сортировщик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77467962?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик (Дербышки)',
#   'vacancy_salary': '33\u202f000 – 36\u202f000 руб.',
#   'min_salary': 33000,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73991855?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-комплектовщик склада Зеленодольск, Технополис Новая Тура, 3',
#   'vacancy_salary': '73\u202f000 – 90\u202f000 руб.',
#   'min_salary': 73000,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77035723?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76738309?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 43\u202f000 руб.',
#   'min_salary': 43000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/55454849?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик в ресторан',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77291998?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик, г. Казань',
#   'vacancy_salary': '33\u202f000 – 36\u202f000 руб.',
#   'min_salary': 33000,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74031912?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77461134?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик, г. Казань',
#   'vacancy_salary': '33\u202f000 – 37\u202f000 руб.',
#   'min_salary': 33000,
#   'max_salary': 37000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76603362?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик, г. Казань',
#   'vacancy_salary': '33\u202f000 – 35\u202f000 руб.',
#   'min_salary': 33000,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76814951?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на производство при ДРКБ',
#   'vacancy_salary': '25\u202f200 – 30\u202f200 руб.',
#   'min_salary': 25200,
#   'max_salary': 30200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74153488?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77282743?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '36\u202f000 – 40\u202f000 руб.',
#   'min_salary': 36000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/51031896?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик мобильной бригады, г. Казань',
#   'vacancy_salary': 'от 61\u202f000 руб.',
#   'min_salary': 61000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77198888?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75573658?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик (со знанием стропальных работ)',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76653781?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 47\u202f700 руб.',
#   'min_salary': 47700,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77200971?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-комплектовщик',
#   'vacancy_salary': 'до 30\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 30000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68290498?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Мерчендайзер-грузчик (Дербышки)',
#   'vacancy_salary': '33\u202f000 – 36\u202f000 руб.',
#   'min_salary': 33000,
#   'max_salary': 36000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73991855?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71819589?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'до 57\u202f200 руб.',
#   'min_salary': None,
#   'max_salary': 57200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77067517?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик мусоровоза',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75939087?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Экспедитор-грузчик',
#   'vacancy_salary': 'до 57\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 57000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76413032?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик (капсульный цех)',
#   'vacancy_salary': 'от 39\u202f000 руб.',
#   'min_salary': 39000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76073667?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '30\u202f000 – 32\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 32000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74009464?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик (с. Столбище)',
#   'vacancy_salary': 'от 50\u202f500 руб.',
#   'min_salary': 50500,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75953788?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-грузчик',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71373566?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '45\u202f000 – 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77134573?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик (Приволжский р-н)',
#   'vacancy_salary': 'от 44\u202f000 руб.',
#   'min_salary': 44000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75791495?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сотрудник склада',
#   'vacancy_salary': 'от 38\u202f500 руб.',
#   'min_salary': 38500,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76258239?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик цех розлива парфюмерии',
#   'vacancy_salary': '31\u202f100 – 31\u202f100 руб.',
#   'min_salary': 31100,
#   'max_salary': 31100,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68256057?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик цех косметики/участок выдува тары',
#   'vacancy_salary': 'от 31\u202f100 руб.',
#   'min_salary': 31100,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/37784356?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '35\u202f000 – 45\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72919878?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик-грузчик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76747883?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик, ул. Амирхана',
#   'vacancy_salary': '20\u202f000 – 28\u202f000 руб.',
#   'min_salary': 20000,
#   'max_salary': 28000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68798088?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '30\u202f000 – 40\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76265421?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'до 38\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 38000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75949595?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-комплектовщик',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/74153531?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': '41\u202f500 – 41\u202f500 руб.',
#   'min_salary': 41500,
#   'max_salary': 41500,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68572014?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75503873?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик на склад готовой продукции',
#   'vacancy_salary': '36\u202f000 – 38\u202f000 руб.',
#   'min_salary': 36000,
#   'max_salary': 38000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76578172?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик в РКБ',
#   'vacancy_salary': '24\u202f000 – 27\u202f300 руб.',
#   'min_salary': 24000,
#   'max_salary': 27300,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/70604264?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик-кладовщик',
#   'vacancy_salary': 'от 35\u202f000 руб.',
#   'min_salary': 35000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72429413?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик на оптовый склад канцтоваров',
#   'vacancy_salary': '30\u202f000 – 45\u202f000 руб.',
#   'min_salary': 30000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76752996?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик (г. Москва)',
#   'vacancy_salary': '69\u202f000 – 158\u202f000 руб.',
#   'min_salary': 69000,
#   'max_salary': 158000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76645692?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист проблемных заказов',
#   'vacancy_salary': 'от 45\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77231585?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сборщик',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71494966?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Грузчик Горячего цеха Комбината питания',
#   'vacancy_salary': 'от 28\u202f000 руб.',
#   'min_salary': 28000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/70604081?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик на склад в г. Казань',
#   'vacancy_salary': '90\u202f000 – 180\u202f000 руб.',
#   'min_salary': 90000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77033356?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сотрудник склада',
#   'vacancy_salary': 'от 43\u202f000 руб.',
#   'min_salary': 43000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77266019?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик/упаковщик на теплый склад в Казани',
#   'vacancy_salary': 'до 89\u202f100 руб.',
#   'min_salary': None,
#   'max_salary': 89100,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77408090?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-комплектовщик склада Зеленодольск, Технополис Новая Тура, 3',
#   'vacancy_salary': '73\u202f000 – 90\u202f000 руб.',
#   'min_salary': 73000,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77035723?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Работник торгового зала на выкладку товара',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76901824?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
# ...
#   'vacancy_salary': 'до 47\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 47000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77449438?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кассир (ул. Глушко)',
#   'vacancy_salary': 'до 28\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 28000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73857397?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор',
#   'vacancy_salary': '34\u202f600 – 47\u202f000 руб.',
#   'min_salary': 34600,
#   'max_salary': 47000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76953439?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик-водитель погрузчика',
#   'vacancy_salary': 'до 37\u202f200 руб.',
#   'min_salary': None,
#   'max_salary': 37200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/68290983?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Водитель-экспедитор',
#   'vacancy_salary': 'от 75\u202f000 руб.',
#   'min_salary': 75000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77434031?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Водитель-экспедитор на Газель Некст',
#   'vacancy_salary': '55\u202f000 – 70\u202f000 руб.',
#   'min_salary': 55000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76350592?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс ( м. Аметьево )',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612139?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс (м. Северный вокзал)',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612386?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик - комплектовщик к партнеру сервиса Яндекс (м. Суконная площадь)',
#   'vacancy_salary': 'от 39\u202f420 руб.',
#   'min_salary': 39420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612205?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик - комплектовщик к партнеру сервиса Яндекс (м. Площадь Тукая)',
#   'vacancy_salary': 'от 39\u202f420 руб.',
#   'min_salary': 39420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612214?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс (м. Козья слобода)',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612368?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс ( м. Площадь Тукая )',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612108?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс ( м. Суконная слобода )',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612023?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начальник автоколлонны',
#   'vacancy_salary': '80\u202f000 – 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77429065?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Заведующий складом',
#   'vacancy_salary': '50\u202f000 – 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 50000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76591953?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс ( м. Аметьево )',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612644?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Продавец-консультант (менеджер торгового зала)',
#   'vacancy_salary': 'от 65\u202f000 руб.',
#   'min_salary': 65000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75862434?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Прессовщик',
#   'vacancy_salary': 'до 57\u202f200 руб.',
#   'min_salary': None,
#   'max_salary': 57200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77333897?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист Службы коменданта',
#   'vacancy_salary': '27\u202f800 – 27\u202f800 руб.',
#   'min_salary': 27800,
#   'max_salary': 27800,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/73990258?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Упаковщик интернет заказов (подработка)',
#   'vacancy_salary': 'до 80\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76628344?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик на склад',
#   'vacancy_salary': '50\u202f000 – 70\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77114676?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тальман (зерновые культуры)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://spb.hh.ru/vacancy/77130002?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор (г. Казань)',
#   'vacancy_salary': '34\u202f600 – 47\u202f000 руб.',
#   'min_salary': 34600,
#   'max_salary': 47000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75788213?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер в отдел продаж',
#   'vacancy_salary': '60\u202f000 – 100\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76143608?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кладовщик/Специалист по приему и подбору товара (Горьковское шоссе)',
#   'vacancy_salary': 'до 40\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/72464386?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Приемосдатчик груза и багажа / Кладовщик мобильной бригады, г. Казань',
#   'vacancy_salary': 'от 70\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75526412?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Заведующий складом',
#   'vacancy_salary': '60\u202f000 – 70\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 70000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76927690?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Работник склада',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/71494288?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кассир (м. Тукая, м. Кремлевская)',
#   'vacancy_salary': 'до 29\u202f900 руб.',
#   'min_salary': None,
#   'max_salary': 29900,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76896709?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ночной упаковщик заказов (подработка)',
#   'vacancy_salary': '120\u202f000 – 145\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 145000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76622085?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ночной упаковщик заказов (подработка)',
#   'vacancy_salary': '120\u202f000 – 145\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 145000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76725678?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Приемщик товара-кладовщик (АШАН ТЦ Парк Хаус)',
#   'vacancy_salary': '33\u202f300 – 39\u202f000 руб.',
#   'min_salary': 33300,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76661871?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Сборщик корзин (АШАН Южный)',
#   'vacancy_salary': '28\u202f130 – 33\u202f690 руб.',
#   'min_salary': 28130,
#   'max_salary': 33690,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76663166?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Приемщик товара (м. Тукая, м. Кремлевская)',
#   'vacancy_salary': 'до 38\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 38000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76649382?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Упаковщик интернет заказов (подработка)',
#   'vacancy_salary': 'до 80\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76630166?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Рабочий на производство',
#   'vacancy_salary': '78\u202f400 – 90\u202f000 руб.',
#   'min_salary': 78400,
#   'max_salary': 90000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76681737?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Помощник-подсобный работник (подработка)',
#   'vacancy_salary': '51\u202f000 – 80\u202f000 руб.',
#   'min_salary': 51000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76628623?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Водитель-курьер Вкусвилл',
#   'vacancy_salary': '70\u202f000 – 120\u202f000 руб.',
#   'min_salary': 70000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76148227?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший кассир (м. Яшьлек)',
#   'vacancy_salary': 'до 35\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 35000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76698544?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Повар по разделке рыбы (АШАН Парк Хаус)',
#   'vacancy_salary': '33\u202f920 – 37\u202f320 руб.',
#   'min_salary': 33920,
#   'max_salary': 37320,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76666562?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Кассир (АШАН Парк Хаус)',
#   'vacancy_salary': '28\u202f130 – 30\u202f850 руб.',
#   'min_salary': 28130,
#   'max_salary': 30850,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76660954?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий продавец-кассир в Перекресток',
#   'vacancy_salary': 'от 40\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/70850638?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Повар (АШАН ТЦ Парк Хаус)',
#   'vacancy_salary': '30\u202f520 – 36\u202f200 руб.',
#   'min_salary': 30520,
#   'max_salary': 36200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76662795?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Комплектовщик к партнеру сервиса Яндекс ( м. Козья слобода )',
#   'vacancy_salary': 'от 34\u202f420 руб.',
#   'min_salary': 34420,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76612307?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер в отдел логистики',
#   'vacancy_salary': '45\u202f000 – 100\u202f000 руб.',
#   'min_salary': 45000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76594732?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Механик',
#   'vacancy_salary': '60\u202f000 – 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': 60000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/75978063?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер по работе с персоналом (Рекрутер)',
#   'vacancy_salary': '32\u202f000 – 40\u202f000 руб.',
#   'min_salary': 32000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://spb.hh.ru/vacancy/76776420?from=vacancy_search_list&query=%D0%93%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA',
#   'vacancy_source': 'hh.ru'}]
